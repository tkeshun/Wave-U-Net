# %% [markdown]
# <a href="https://colab.research.google.com/github/tkeshun/Wave-U-Net/blob/master/test_wave_U_net.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#GPUの確認
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
    process = psutil.Process(os.getpid())
    print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
    print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()
# Out:
# ...
#   Created wheel for gputil: filename=GPUtil-1.4.0-cp36-none-any.whl size=7413 sha256=1d9e79828e3a4c17163c596fa5bd9aac8c09333625057903016a92e04162a585
#   Stored in directory: /root/.cache/pip/wheels/3d/77/07/80562de4bb0786e5ea186911a2c831fdd0018bda69beab71fd
# Successfully built gputil
# ...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-a1c57e50b399> in <module>()
#      10 GPUs = GPU.getGPUs()
#      11 # XXX: only one GPU on Colab and isn’t guaranteed
# ---> 12 gpu = GPUs[0]
#      13 def printm():
#      14     process = psutil.Process(os.getpid())
#
# IndexError: list index out of range

# %%
# !nvidia-smi
# Out:
# Fri Jun 12 14:56:21 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.67       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 14421976966588385537, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 2458342689999031844
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 12341561410020188820
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15701463552
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 13905416693307650981
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %%
#google driveマウント
# %tensorflow_version 1.x
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
"""
ディレクトリ設定
出来なかったらマウントしてあるか確認
"""
import sys
import os
sys.path.append('/content/gdrive/My Drive/search/Wave-U-net/Wave-U-Net/')
os.chdir('/content/gdrive/My Drive/search/Wave-U-net/Wave-U-Net/')
#移動できたか確認
# !pwd
# !ls
# Out:
# /content/gdrive/My Drive/search/Wave-U-net/Wave-U-Net
#  audio_examples
#  CCMixter.xml
#  checkpoints
#  Config.py
#  data
#  Datasets.py
#  Evaluate.py
#  Input
#  LICENSE
#  logs
#  Models
# 'musb_005_angela thomas wade_audio_model_without_context_cut_28234samples_61002samples_93770samples_126538.wav'
#  Plot.py
#  Predict.py
#  __pycache__
#  README.md
#  requirements.txt
#  Source_Estimates
#  Test.py
#  Training.py
#  Utils.py
#  waveunet.png

# %%
#git clone
#!git clone https://github.com/tkeshun/Wave-U-Net.git

# %%
#ユーザ名とメールアドレスを設定
# !git config --global user.email "shun9646@gmail.com"
# !git config --global user.name "tkeshun"

# %%
#必要なパッケージをまとめてダウンロード
# !pip install -r requirements.txt
#version検証のため個別で入力
#gast0.3からNum定数はない,gast0.2.2まではある https://github.com/tensorflow/tensorflow/issues/32319
"""
numpy==1.15.4
sacred==0.7.3
tensorflow===1.8.0
tensorflow-gpu==1.8.0
librosa==0.6.2
soundfile==0.10.2
lxml==4.2.1
musdb==0.2.3
museval==0.2.0
google==2.0.1
protobuf
gast==0.2.2
"""
# Out:
# ...
# '\nnumpy==1.15.4\nsacred==0.7.3\ntensorflow===1.8.0\ntensorflow-gpu==1.8.0\nlibrosa==0.6.2\nsoundfile==0.10.2\nlxml==4.2.1\nmusdb==0.2.3\nmuseval==0.2.0\ngoogle==2.0.1\nprotobuf\ngast==0.2.2\n'

# %%
#install したあとにGPU認識しているか確認
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 3677782698045204518, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 6010474725845800340
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 12469336667540523150
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15701463552
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 2416746413403621014
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %%
#python version 確認
# !python --version 
#tensorflow-gpu version
# !pip freeze
#CUDA
# !nvcc -V
# Out:
# Python 3.6.9
# absl-py==0.9.0
# alabaster==0.7.12
# albumentations==0.1.12
# altair==4.1.0
# asgiref==3.2.7
# astor==0.8.1
# astropy==4.0.1.post1
# astunparse==1.6.3
# atari-py==0.2.6
# atomicwrites==1.4.0
# attrs==19.3.0
# audioread==2.1.8
# autograd==1.3
# Babel==2.8.0
# backcall==0.2.0
# beautifulsoup4==4.6.3
# bleach==3.1.5
# blis==0.4.1
# bokeh==1.4.0
# boto==2.49.0
# boto3==1.13.23
# botocore==1.16.23
# Bottleneck==1.3.2
# branca==0.4.1
# bs4==0.0.1
# CacheControl==0.12.6
# cachetools==3.1.1
# catalogue==1.0.0
# certifi==2020.4.5.1
# cffi==1.14.0
# chainer==6.5.0
# chardet==3.0.4
# click==7.1.2
# cloudpickle==1.3.0
# cmake==3.12.0
# cmdstanpy==0.4.0
# colorlover==0.3.0
# community==1.0.0b1
# contextlib2==0.5.5
# convertdate==2.2.1
# coverage==3.7.1
# coveralls==0.5
# crcmod==1.7
# cufflinks==0.17.3
# cupy-cuda101==6.5.0
# cvxopt==1.2.5
# cvxpy==1.0.31
# cycler==0.10.0
# cymem==2.0.3
# Cython==0.29.19
# daft==0.0.4
# dask==2.12.0
# dataclasses==0.7
# datascience==0.10.6
# ...

# %%
"""
tensorflow_gpu
python
cuDNN
CUDA
のバージョンを合わせる
"""

# %%
# !nvidia-smi
# !free -h
# Out:
# Fri Jun 12 15:02:55 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.67       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    31W / 250W |    353MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
#GPUのナンバー指定
# !export CUDA_VISIBLE_DEVICES="0"

# %%
#動かせるか確認
# !python Training.py
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# Finish 1 loop
# TRAIN SEPARATOR
# Start Increment step counter
# Finish 1 loop
# TRAIN SEPARATOR
# Start Increment step counter
# Finish 1 loop
# TRAIN SEPARATOR
# Start Increment step counter
# Finish 1 loop
# TRAIN SEPARATOR
# Start Increment step counter
# Finish 1 loop
# TRAIN SEPARATOR
# Start Increment step counter
# Finish 1 loop
# TRAIN SEPARATOR
# Start Increment step counter
# Finish 1 loop
# TRAIN SEPARATOR
# Start Increment step counter
# Finish 1 loop
# TRAIN SEPARATOR
# Start Increment step counter
# Finish 1 loop
# TRAIN SEPARATOR
# Start Increment step counter
# Finish 1 loop
# TRAIN SEPARATOR
# Start Increment step counter
# Finish 1 loop
# TRAIN SEPARATOR
# Start Increment step counter
# Finish 1 loop
# TRAIN SEPARATOR
# Start Increment step counter
# Finish 1 loop
# TRAIN SEPARATOR
# Start Increment step counter
# Finish 1 loop
# TRAIN SEPARATOR
# Start Increment step counter
# Finish 1 loop
# TRAIN SEPARATOR
# ...

# %%
#predictだけやってみる
#Training.pyのcheckpointを復元する
# !python Predict.py with cfg.baseline model_path="/content/gdrive/My Drive/search/Wave-U-net/Wave-U-Net/checkpoints/284018/284018-2400" input_path="/content/gdrive/My Drive/search/data/musdb18/" output_path="/content/gdrive/My Drive/search/Wave-U-net/Wave-U-Net/Source_Estimates"
# Out:
# Training baseline model
# WARNING - Waveunet Prediction - No observers have been added to this run
# INFO - Waveunet Prediction - Running command 'main'
# INFO - Waveunet Prediction - Started
# Evaluating trained model saved at /content/gdrive/My Drive/search/Wave-U-net/Wave-U-Net/checkpoints/284018/284018-2400 on MUSDB and saving source estimate audio to /content/gdrive/My Drive/search/Wave-U-net/Wave-U-Net/Source_Estimates
# Testing...
# WARNING:tensorflow:From /content/gdrive/My Drive/search/Wave-U-net/Wave-U-Net/Models/UnetAudioSeparator.py:98: conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.conv1d instead.
# WARNING - tensorflow - From /content/gdrive/My Drive/search/Wave-U-net/Wave-U-Net/Models/UnetAudioSeparator.py:98: conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa itlb_multihit
# bogomips	: 4400.00
# ...

# %% [markdown]
# ###リポジトリ情報を明示的に記述してOriginを設定
#
# Colabでは、下記のように明示的にoriginに認証情報（ユーザ名、パスワード）を渡して設定する必要があります
#
# ```
# !git remote set-url origin https://username:password@github.com/reponame.git
# !git push origin master
# ```

# %%
"""
# !git remote set-url origin
# !git push 
"""
